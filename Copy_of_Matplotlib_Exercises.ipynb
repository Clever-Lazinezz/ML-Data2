# %% [markdown]
# <a href="https://colab.research.google.com/github/Clever-Lazinezz/ML-Data2/blob/main/Copy_of_Matplotlib_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib Exercises
#
# MatPlotLib Review!
#
# Take your time, Matplotlib can be tricky to understand at first.
#
# These should be relatively simple plots, however they can be hard if this is your first time with matplotlib, please feel free to reference the site documentation as you go along.
#
# # Exercises
#
# ## Data

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %% [markdown]
# ## Exercise 1
#
# * **Create a figure object called fig using plt.figure() **
# * **Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * **Plot (x,y) on that axes and set the labels and titles to match the plot below: **

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color='blue',linewidth=1.0)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
ax.set_xlim(left=0,right=100)
ax.set_ylim(bottom=0,top=200)
# Out:
# (0.0, 200.0)

# %% [markdown]
# ## Exercise 2
# **Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])

# %% [markdown]
# **Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('title')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_title('title')
ax1.plot(x,y,linewidth=1.0,color='red')
ax2.plot(x,y,linewidth=1.0,color='red')
ax1.set_xlim(left=0,right=100)
ax1.set_ylim(bottom=0,top=200)
ax2.set_xlim(left=0,right=100)
ax2.set_ylim(bottom=0,top=200)
fig

# %% [markdown]
# ## Exercise 3
#
# **Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure()
ax3 = fig.add_axes([0,0,1,1])
ax4 = fig.add_axes([.2,.5,.4,.4])

# %% [markdown]
# **Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
ax3.set_xlabel('x')
ax3.set_ylabel('z')
ax3.plot(x,z,linewidth=1.0,color='blue')
ax3.set_xlim(left=0,right=100)
ax3.set_ylim(bottom=0,top=10000)

ax4.set_xlabel('x')
ax4.set_ylabel('y')
ax4.set_title('Zoom')
ax4.plot(x,y,color = 'blue',linewidth=1.0)
ax4.set_xlim(left=20,right=22)
ax4.set_ylim(bottom=30,top=50)
fig
fig

# %% [markdown]
# ## Exercise 4
#
# **Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

# %% [markdown]
# **Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
axes[0].plot(x,y,linewidth=2.0,color='blue',ls='--')
axes[1].plot(x,z,color='red',linewidth=2.0)
axes[0].set_xlim(left=0,right=100)
axes[1].set_xlim(left=0,right=100)
axes[0].set_ylim(bottom=0,top=200)
axes[1].set_ylim(bottom=0)
fig

# %% [markdown]
# *See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.*

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(12,2))

axes[0].plot(x,y,color="blue", lw=5)
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')

axes[1].plot(x,z,color="red", lw=3, ls='--')
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')
# Out:
# Text(0, 0.5, 'z')

# %% [markdown]
# # Cheers!
